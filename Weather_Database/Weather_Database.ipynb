# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
import citipy

# %%
# Create a list for holding the cities.
nearest_cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in nearest_cities:
        nearest_cities.append(city)
# Print the city count to confirm sufficient count.
len(nearest_cities)
# Out:
# 759

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(nearest_cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description= city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | east london
# Processing Record 2 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | kargil
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | tabasco
# Processing Record 9 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | luanda
# Processing Record 12 of Set 1 | tuktoyaktuk
# Processing Record 13 of Set 1 | ostrovnoy
# Processing Record 14 of Set 1 | yumen
# Processing Record 15 of Set 1 | madanapalle
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | southend-on-sea
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | jujuy
# City not found. Skipping...
# Processing Record 22 of Set 1 | mahebourg
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | nikolskoye
# Processing Record 25 of Set 1 | cockburn town
# Processing Record 26 of Set 1 | klaksvik
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | antofagasta
# Processing Record 31 of Set 1 | makakilo city
# Processing Record 32 of Set 1 | necochea
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | hilo
# Processing Record 35 of Set 1 | bria
# Processing Record 36 of Set 1 | landerneau
# Processing Record 37 of Set 1 | seymchan
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | mount gambier
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | bethel
# Processing Record 42 of Set 1 | alcudia
# Processing Record 43 of Set 1 | bowen
# Processing Record 44 of Set 1 | meulaboh
# Processing Record 45 of Set 1 | jamestown
# Processing Record 46 of Set 1 | la paz
# Processing Record 47 of Set 1 | bathsheba
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | tutoia
# Processing Record 1 of Set 2 | thinadhoo
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | waipawa
# Processing Record 4 of Set 2 | marzuq
# Processing Record 5 of Set 2 | santiago
# Processing Record 6 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | svoge
# Processing Record 11 of Set 2 | clyde river
# Processing Record 12 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 2 | kamenicky senov
# Processing Record 14 of Set 2 | isangel
# Processing Record 15 of Set 2 | guane
# Processing Record 16 of Set 2 | chuy
# Processing Record 17 of Set 2 | kahului
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | lagoa
# Processing Record 20 of Set 2 | dikson
# Processing Record 21 of Set 2 | touros
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | atambua
# Processing Record 24 of Set 2 | jaru
# Processing Record 25 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | hofn
# Processing Record 29 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | sambava
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | goderich
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | alofi
# Processing Record 36 of Set 2 | carnarvon
# Processing Record 37 of Set 2 | galle
# Processing Record 38 of Set 2 | olinda
# Processing Record 39 of Set 2 | awjilah
# Processing Record 40 of Set 2 | radeberg
# Processing Record 41 of Set 2 | la baule-escoublac
# Processing Record 42 of Set 2 | eirunepe
# Processing Record 43 of Set 2 | san andres
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | hithadhoo
# Processing Record 46 of Set 2 | nanortalik
# Processing Record 47 of Set 2 | caxito
# Processing Record 48 of Set 2 | samarai
# Processing Record 49 of Set 2 | kirakira
# Processing Record 50 of Set 2 | codrington
# Processing Record 1 of Set 3 | thompson
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 3 | mackenzie
# Processing Record 5 of Set 3 | sorland
# Processing Record 6 of Set 3 | mayskiy
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | tomatlan
# Processing Record 9 of Set 3 | castro
# Processing Record 10 of Set 3 | bontang
# Processing Record 11 of Set 3 | nioro
# Processing Record 12 of Set 3 | arraial do cabo
# Processing Record 13 of Set 3 | balakhta
# Processing Record 14 of Set 3 | dudley
# Processing Record 15 of Set 3 | vila franca do campo
# Processing Record 16 of Set 3 | sakaiminato
# Processing Record 17 of Set 3 | san jeronimo
# Processing Record 18 of Set 3 | paradise
# Processing Record 19 of Set 3 | lumeje
# Processing Record 20 of Set 3 | ribeira grande
# Processing Record 21 of Set 3 | priargunsk
# Processing Record 22 of Set 3 | margate
# Processing Record 23 of Set 3 | progreso
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | champerico
# Processing Record 26 of Set 3 | pudozh
# Processing Record 27 of Set 3 | cabo san lucas
# Processing Record 28 of Set 3 | dengfeng
# Processing Record 29 of Set 3 | chokurdakh
# Processing Record 30 of Set 3 | senneterre
# Processing Record 31 of Set 3 | pahrump
# Processing Record 32 of Set 3 | bandarbeyla
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | avera
# Processing Record 35 of Set 3 | cabedelo
# Processing Record 36 of Set 3 | norman wells
# Processing Record 37 of Set 3 | arkadelphia
# Processing Record 38 of Set 3 | san jose
# Processing Record 39 of Set 3 | tagusao
# Processing Record 40 of Set 3 | tommot
# Processing Record 41 of Set 3 | kununurra
# Processing Record 42 of Set 3 | mar del plata
# Processing Record 43 of Set 3 | axim
# Processing Record 44 of Set 3 | alyangula
# Processing Record 45 of Set 3 | karla
# Processing Record 46 of Set 3 | pitimbu
# Processing Record 47 of Set 3 | westpunt
# City not found. Skipping...
# Processing Record 48 of Set 3 | beyneu
# Processing Record 49 of Set 3 | mandalgovi
# Processing Record 50 of Set 3 | haines junction
# Processing Record 1 of Set 4 | quelimane
# Processing Record 2 of Set 4 | ijaki
# City not found. Skipping...
# Processing Record 3 of Set 4 | airai
# Processing Record 4 of Set 4 | isiro
# Processing Record 5 of Set 4 | talnakh
# Processing Record 6 of Set 4 | tessalit
# Processing Record 7 of Set 4 | cape town
# Processing Record 8 of Set 4 | adrar
# Processing Record 9 of Set 4 | rocha
# Processing Record 10 of Set 4 | mahibadhoo
# Processing Record 11 of Set 4 | ameca
# Processing Record 12 of Set 4 | saint george
# Processing Record 13 of Set 4 | port lincoln
# Processing Record 14 of Set 4 | buchanan
# Processing Record 15 of Set 4 | shkotovo-22
# City not found. Skipping...
# Processing Record 16 of Set 4 | saint-augustin
# Processing Record 17 of Set 4 | atasu
# Processing Record 18 of Set 4 | san rafael
# Processing Record 19 of Set 4 | albany
# Processing Record 20 of Set 4 | vanimo
# Processing Record 21 of Set 4 | alamosa
# Processing Record 22 of Set 4 | college
# Processing Record 23 of Set 4 | shaowu
# Processing Record 24 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 4 | okha
# Processing Record 26 of Set 4 | la ronge
# Processing Record 27 of Set 4 | umm kaddadah
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | longyearbyen
# Processing Record 30 of Set 4 | kabinda
# Processing Record 31 of Set 4 | sao filipe
# Processing Record 32 of Set 4 | mount isa
# Processing Record 33 of Set 4 | vila velha
# Processing Record 34 of Set 4 | nuuk
# Processing Record 35 of Set 4 | port blair
# Processing Record 36 of Set 4 | bac can
# City not found. Skipping...
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | inhambane
# Processing Record 39 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 4 | dingle
# Processing Record 41 of Set 4 | port hardy
# Processing Record 42 of Set 4 | luwuk
# Processing Record 43 of Set 4 | hermiston
# Processing Record 44 of Set 4 | hasaki
# Processing Record 45 of Set 4 | bemidji
# Processing Record 46 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 4 | quatre cocos
# Processing Record 48 of Set 4 | phalaborwa
# Processing Record 49 of Set 4 | kaitangata
# Processing Record 50 of Set 4 | fairbanks
# Processing Record 1 of Set 5 | mogadishu
# Processing Record 2 of Set 5 | bredasdorp
# Processing Record 3 of Set 5 | kintinku
# Processing Record 4 of Set 5 | jibuti
# Processing Record 5 of Set 5 | soyo
# Processing Record 6 of Set 5 | urumqi
# Processing Record 7 of Set 5 | jomalig
# City not found. Skipping...
# Processing Record 8 of Set 5 | tateyama
# Processing Record 9 of Set 5 | narok
# Processing Record 10 of Set 5 | te anau
# Processing Record 11 of Set 5 | upata
# Processing Record 12 of Set 5 | bonavista
# Processing Record 13 of Set 5 | tiksi
# Processing Record 14 of Set 5 | tual
# Processing Record 15 of Set 5 | shwebo
# Processing Record 16 of Set 5 | beloha
# Processing Record 17 of Set 5 | dharampur
# Processing Record 18 of Set 5 | wanaka
# Processing Record 19 of Set 5 | smidovich
# Processing Record 20 of Set 5 | katav-ivanovsk
# Processing Record 21 of Set 5 | nizwa
# Processing Record 22 of Set 5 | vechta
# Processing Record 23 of Set 5 | partyzany
# Processing Record 24 of Set 5 | mamlyutka
# Processing Record 25 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 5 | iqaluit
# Processing Record 27 of Set 5 | dabakala
# Processing Record 28 of Set 5 | kavieng
# Processing Record 29 of Set 5 | biak
# Processing Record 30 of Set 5 | half moon bay
# Processing Record 31 of Set 5 | grand-santi
# Processing Record 32 of Set 5 | tevaitoa
# Processing Record 33 of Set 5 | nabinagar
# Processing Record 34 of Set 5 | linxia
# Processing Record 35 of Set 5 | pinega
# Processing Record 36 of Set 5 | cidreira
# Processing Record 37 of Set 5 | maceio
# Processing Record 38 of Set 5 | port elizabeth
# Processing Record 39 of Set 5 | saint-louis
# Processing Record 40 of Set 5 | harper
# Processing Record 41 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 5 | santa marta
# Processing Record 43 of Set 5 | dakoro
# Processing Record 44 of Set 5 | baykit
# Processing Record 45 of Set 5 | basse
# Processing Record 46 of Set 5 | rio gallegos
# Processing Record 47 of Set 5 | carlibaba
# Processing Record 48 of Set 5 | sioux lookout
# Processing Record 49 of Set 5 | guacui
# Processing Record 50 of Set 5 | sistranda
# Processing Record 1 of Set 6 | saint-joseph
# Processing Record 2 of Set 6 | sangar
# Processing Record 3 of Set 6 | qandala
# Processing Record 4 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 6 | simao
# Processing Record 6 of Set 6 | ormara
# Processing Record 7 of Set 6 | ambilobe
# Processing Record 8 of Set 6 | zhuhai
# Processing Record 9 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 6 | esperance
# Processing Record 11 of Set 6 | okhotsk
# Processing Record 12 of Set 6 | scottsburgh
# City not found. Skipping...
# Processing Record 13 of Set 6 | zhangye
# Processing Record 14 of Set 6 | mahajanga
# Processing Record 15 of Set 6 | bubaque
# Processing Record 16 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 6 | kidal
# Processing Record 18 of Set 6 | constitucion
# Processing Record 19 of Set 6 | husavik
# Processing Record 20 of Set 6 | aksha
# Processing Record 21 of Set 6 | nisia floresta
# Processing Record 22 of Set 6 | santa cruz del sur
# Processing Record 23 of Set 6 | sumbe
# Processing Record 24 of Set 6 | cherskiy
# Processing Record 25 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 6 | bac lieu
# Processing Record 27 of Set 6 | araouane
# Processing Record 28 of Set 6 | kalmunai
# Processing Record 29 of Set 6 | sur
# Processing Record 30 of Set 6 | arys
# Processing Record 31 of Set 6 | raudeberg
# Processing Record 32 of Set 6 | kloulklubed
# Processing Record 33 of Set 6 | vardo
# Processing Record 34 of Set 6 | jaguarao
# Processing Record 35 of Set 6 | menongue
# Processing Record 36 of Set 6 | sola
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | narsaq
# Processing Record 39 of Set 6 | yeppoon
# Processing Record 40 of Set 6 | buraydah
# Processing Record 41 of Set 6 | san onofre
# Processing Record 42 of Set 6 | pisco
# Processing Record 43 of Set 6 | zlobin
# Processing Record 44 of Set 6 | namibe
# Processing Record 45 of Set 6 | torbay
# Processing Record 46 of Set 6 | hami
# Processing Record 47 of Set 6 | ereymentau
# Processing Record 48 of Set 6 | maku
# Processing Record 49 of Set 6 | parakan
# Processing Record 50 of Set 6 | ahipara
# Processing Record 1 of Set 7 | valdivia
# Processing Record 2 of Set 7 | gwanda
# Processing Record 3 of Set 7 | balabac
# Processing Record 4 of Set 7 | merke
# Processing Record 5 of Set 7 | bitung
# Processing Record 6 of Set 7 | san luis
# Processing Record 7 of Set 7 | conceicao do araguaia
# Processing Record 8 of Set 7 | zhigansk
# Processing Record 9 of Set 7 | hualmay
# Processing Record 10 of Set 7 | tocopilla
# Processing Record 11 of Set 7 | iracoubo
# Processing Record 12 of Set 7 | broken hill
# Processing Record 13 of Set 7 | coro
# Processing Record 14 of Set 7 | acapulco
# Processing Record 15 of Set 7 | nortelandia
# Processing Record 16 of Set 7 | kurilsk
# Processing Record 17 of Set 7 | sitka
# Processing Record 18 of Set 7 | nabire
# Processing Record 19 of Set 7 | san cristobal
# Processing Record 20 of Set 7 | pemba
# Processing Record 21 of Set 7 | tukrah
# Processing Record 22 of Set 7 | tautira
# Processing Record 23 of Set 7 | burma
# Processing Record 24 of Set 7 | kohat
# Processing Record 25 of Set 7 | sarkand
# Processing Record 26 of Set 7 | henties bay
# Processing Record 27 of Set 7 | bama
# Processing Record 28 of Set 7 | palu
# Processing Record 29 of Set 7 | west melbourne
# Processing Record 30 of Set 7 | havre-saint-pierre
# Processing Record 31 of Set 7 | viet tri
# Processing Record 32 of Set 7 | bilibino
# Processing Record 33 of Set 7 | tabas
# Processing Record 34 of Set 7 | provideniya
# Processing Record 35 of Set 7 | benin
# Processing Record 36 of Set 7 | gamba
# Processing Record 37 of Set 7 | quevedo
# Processing Record 38 of Set 7 | abu samrah
# Processing Record 39 of Set 7 | nur
# Processing Record 40 of Set 7 | nosy varika
# Processing Record 41 of Set 7 | birakan
# Processing Record 42 of Set 7 | vostok
# Processing Record 43 of Set 7 | lesnoy
# Processing Record 44 of Set 7 | jurado
# Processing Record 45 of Set 7 | mapiripan
# Processing Record 46 of Set 7 | barinas
# Processing Record 47 of Set 7 | pevek
# Processing Record 48 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 7 | port-gentil
# Processing Record 50 of Set 7 | san quintin
# Processing Record 1 of Set 8 | manavalakurichi
# Processing Record 2 of Set 8 | sokolka
# Processing Record 3 of Set 8 | santa vitoria do palmar
# Processing Record 4 of Set 8 | los llanos de aridane
# Processing Record 5 of Set 8 | sinnamary
# Processing Record 6 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 7 of Set 8 | caucaia
# Processing Record 8 of Set 8 | elko
# Processing Record 9 of Set 8 | newton
# Processing Record 10 of Set 8 | the valley
# Processing Record 11 of Set 8 | diamantino
# Processing Record 12 of Set 8 | sao francisco
# Processing Record 13 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 8 | aykhal
# Processing Record 15 of Set 8 | bouafle
# Processing Record 16 of Set 8 | ngunguru
# Processing Record 17 of Set 8 | imbituba
# Processing Record 18 of Set 8 | ilulissat
# Processing Record 19 of Set 8 | taltal
# Processing Record 20 of Set 8 | copiapo
# Processing Record 21 of Set 8 | astipalaia
# City not found. Skipping...
# Processing Record 22 of Set 8 | bure
# Processing Record 23 of Set 8 | konevo
# Processing Record 24 of Set 8 | mangochi
# Processing Record 25 of Set 8 | dunmore east
# Processing Record 26 of Set 8 | innoshima
# Processing Record 27 of Set 8 | beringovskiy
# Processing Record 28 of Set 8 | alice
# Processing Record 29 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 8 | atar
# Processing Record 31 of Set 8 | fallon
# Processing Record 32 of Set 8 | severo-kurilsk
# Processing Record 33 of Set 8 | beitbridge
# Processing Record 34 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 8 | whitecourt
# Processing Record 36 of Set 8 | mayya
# Processing Record 37 of Set 8 | piltene
# Processing Record 38 of Set 8 | tshikapa
# Processing Record 39 of Set 8 | yuxia
# Processing Record 40 of Set 8 | rawson
# Processing Record 41 of Set 8 | hastings
# Processing Record 42 of Set 8 | kaeo
# Processing Record 43 of Set 8 | bytow
# Processing Record 44 of Set 8 | maiduguri
# Processing Record 45 of Set 8 | bambanglipuro
# Processing Record 46 of Set 8 | vestmanna
# Processing Record 47 of Set 8 | uyemskiy
# Processing Record 48 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 8 | shingu
# Processing Record 50 of Set 8 | loreto
# Processing Record 1 of Set 9 | coolum beach
# Processing Record 2 of Set 9 | shumskiy
# Processing Record 3 of Set 9 | springfield
# Processing Record 4 of Set 9 | skibbereen
# Processing Record 5 of Set 9 | toppenish
# Processing Record 6 of Set 9 | almonte
# Processing Record 7 of Set 9 | snyder
# Processing Record 8 of Set 9 | narimanov
# Processing Record 9 of Set 9 | sanchursk
# Processing Record 10 of Set 9 | teguldet
# Processing Record 11 of Set 9 | vagay
# Processing Record 12 of Set 9 | beni
# Processing Record 13 of Set 9 | takoradi
# Processing Record 14 of Set 9 | herat
# Processing Record 15 of Set 9 | mangrol
# Processing Record 16 of Set 9 | tilichiki
# Processing Record 17 of Set 9 | diego de almagro
# Processing Record 18 of Set 9 | kargasok
# Processing Record 19 of Set 9 | geraldton
# Processing Record 20 of Set 9 | sarab
# Processing Record 21 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 22 of Set 9 | jackson
# Processing Record 23 of Set 9 | trincomalee
# Processing Record 24 of Set 9 | saint anthony
# Processing Record 25 of Set 9 | tura
# Processing Record 26 of Set 9 | puerto penasco
# Processing Record 27 of Set 9 | hamilton
# Processing Record 28 of Set 9 | tarko-sale
# Processing Record 29 of Set 9 | lavrentiya
# Processing Record 30 of Set 9 | abay
# Processing Record 31 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 9 | victoria point
# Processing Record 33 of Set 9 | shimoda
# Processing Record 34 of Set 9 | fort morgan
# Processing Record 35 of Set 9 | meiganga
# Processing Record 36 of Set 9 | dalvik
# Processing Record 37 of Set 9 | padang
# Processing Record 38 of Set 9 | mayo
# Processing Record 39 of Set 9 | linqu
# Processing Record 40 of Set 9 | zaysan
# Processing Record 41 of Set 9 | muli
# Processing Record 42 of Set 9 | icanti
# City not found. Skipping...
# Processing Record 43 of Set 9 | saginaw
# Processing Record 44 of Set 9 | nadvoitsy
# Processing Record 45 of Set 9 | belmonte
# Processing Record 46 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 9 | kendari
# Processing Record 48 of Set 9 | kavaratti
# Processing Record 49 of Set 9 | ji-parana
# City not found. Skipping...
# Processing Record 50 of Set 9 | turukhansk
# Processing Record 1 of Set 10 | san vicente
# Processing Record 2 of Set 10 | donskoye
# Processing Record 3 of Set 10 | boguchany
# Processing Record 4 of Set 10 | port-de-paix
# City not found. Skipping...
# Processing Record 5 of Set 10 | jacksonville
# Processing Record 6 of Set 10 | winchester
# Processing Record 7 of Set 10 | wingham
# Processing Record 8 of Set 10 | uarini
# Processing Record 9 of Set 10 | ronne
# Processing Record 10 of Set 10 | tuatapere
# Processing Record 11 of Set 10 | ilhabela
# Processing Record 12 of Set 10 | frontera
# Processing Record 13 of Set 10 | assiniboia
# Processing Record 14 of Set 10 | verkhoyansk
# Processing Record 15 of Set 10 | manaure
# Processing Record 16 of Set 10 | okawa
# Processing Record 17 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 10 | leningradskiy
# Processing Record 19 of Set 10 | salalah
# Processing Record 20 of Set 10 | ajdabiya
# Processing Record 21 of Set 10 | scarborough
# Processing Record 22 of Set 10 | agirish
# Processing Record 23 of Set 10 | mitsamiouli
# Processing Record 24 of Set 10 | faanui
# Processing Record 25 of Set 10 | new bern
# Processing Record 26 of Set 10 | itamaraca
# Processing Record 27 of Set 10 | aldan
# Processing Record 28 of Set 10 | aksu
# Processing Record 29 of Set 10 | agadez
# Processing Record 30 of Set 10 | guilin
# Processing Record 31 of Set 10 | agva
# City not found. Skipping...
# Processing Record 32 of Set 10 | rio grande
# Processing Record 33 of Set 10 | ulma
# Processing Record 34 of Set 10 | prince george
# Processing Record 35 of Set 10 | jinchang
# Processing Record 36 of Set 10 | pokhara
# Processing Record 37 of Set 10 | hermosillo
# Processing Record 38 of Set 10 | bagh
# Processing Record 39 of Set 10 | gien
# Processing Record 40 of Set 10 | havoysund
# Processing Record 41 of Set 10 | solnechnyy
# Processing Record 42 of Set 10 | lazaro cardenas
# Processing Record 43 of Set 10 | tornio
# Processing Record 44 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 45 of Set 10 | aklavik
# Processing Record 46 of Set 10 | mackay
# Processing Record 47 of Set 10 | teya
# Processing Record 48 of Set 10 | evensk
# Processing Record 49 of Set 10 | komsomolskiy
# Processing Record 50 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 1 of Set 11 | taonan
# Processing Record 2 of Set 11 | fukue
# Processing Record 3 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 11 | pomorie
# Processing Record 5 of Set 11 | lakatoro
# Processing Record 6 of Set 11 | batemans bay
# Processing Record 7 of Set 11 | tamara
# Processing Record 8 of Set 11 | alice springs
# Processing Record 9 of Set 11 | naryan-mar
# Processing Record 10 of Set 11 | bandarban
# Processing Record 11 of Set 11 | dubbo
# Processing Record 12 of Set 11 | newport
# Processing Record 13 of Set 11 | srednekolymsk
# Processing Record 14 of Set 11 | paslek
# Processing Record 15 of Set 11 | coruripe
# Processing Record 16 of Set 11 | basco
# Processing Record 17 of Set 11 | labuan
# Processing Record 18 of Set 11 | vyartsilya
# Processing Record 19 of Set 11 | vanderhoof
# Processing Record 20 of Set 11 | hovd
# Processing Record 21 of Set 11 | dharchula
# Processing Record 22 of Set 11 | masterton
# Processing Record 23 of Set 11 | prince rupert
# Processing Record 24 of Set 11 | olafsvik
# Processing Record 25 of Set 11 | piacabucu
# Processing Record 26 of Set 11 | kruisfontein
# Processing Record 27 of Set 11 | itanhandu
# Processing Record 28 of Set 11 | impfondo
# Processing Record 29 of Set 11 | swellendam
# Processing Record 30 of Set 11 | krasnoselkup
# Processing Record 31 of Set 11 | ibra
# Processing Record 32 of Set 11 | viedma
# Processing Record 33 of Set 11 | grindavik
# Processing Record 34 of Set 11 | kautokeino
# Processing Record 35 of Set 11 | gat
# Processing Record 36 of Set 11 | gubkinskiy
# Processing Record 37 of Set 11 | ulladulla
# Processing Record 38 of Set 11 | ahuimanu
# Processing Record 39 of Set 11 | baijiantan
# Processing Record 40 of Set 11 | qaqortoq
# Processing Record 41 of Set 11 | nalut
# Processing Record 42 of Set 11 | pervomayskoye
# Processing Record 43 of Set 11 | dunedin
# Processing Record 44 of Set 11 | bardiyah
# Processing Record 45 of Set 11 | naushki
# Processing Record 46 of Set 11 | rutland
# Processing Record 47 of Set 11 | abha
# Processing Record 48 of Set 11 | huainan
# Processing Record 49 of Set 11 | rapid valley
# Processing Record 50 of Set 11 | vung tau
# Processing Record 1 of Set 12 | khandyga
# Processing Record 2 of Set 12 | nouadhibou
# Processing Record 3 of Set 12 | poum
# Processing Record 4 of Set 12 | christchurch
# Processing Record 5 of Set 12 | huilong
# Processing Record 6 of Set 12 | vuktyl
# Processing Record 7 of Set 12 | isabela
# Processing Record 8 of Set 12 | matara
# Processing Record 9 of Set 12 | mehamn
# Processing Record 10 of Set 12 | paita
# Processing Record 11 of Set 12 | barranca
# Processing Record 12 of Set 12 | tiznit
# Processing Record 13 of Set 12 | la macarena
# Processing Record 14 of Set 12 | medicine hat
# Processing Record 15 of Set 12 | malangwa
# Processing Record 16 of Set 12 | walvis bay
# Processing Record 17 of Set 12 | morondava
# Processing Record 18 of Set 12 | orbetello
# Processing Record 19 of Set 12 | bengkulu
# Processing Record 20 of Set 12 | canavieiras
# Processing Record 21 of Set 12 | ancud
# Processing Record 22 of Set 12 | kathu
# Processing Record 23 of Set 12 | fort nelson
# Processing Record 24 of Set 12 | namatanai
# Processing Record 25 of Set 12 | yulara
# Processing Record 26 of Set 12 | imuris
# Processing Record 27 of Set 12 | yong peng
# Processing Record 28 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 12 | forio
# Processing Record 30 of Set 12 | chicama
# Processing Record 31 of Set 12 | jiangyou
# Processing Record 32 of Set 12 | cayenne
# Processing Record 33 of Set 12 | yerbogachen
# Processing Record 34 of Set 12 | mount vernon
# Processing Record 35 of Set 12 | zeya
# Processing Record 36 of Set 12 | mercedes
# Processing Record 37 of Set 12 | tuyen quang
# Processing Record 38 of Set 12 | zatoka
# Processing Record 39 of Set 12 | natal
# Processing Record 40 of Set 12 | byron bay
# Processing Record 41 of Set 12 | ugoofaaru
# Processing Record 42 of Set 12 | mount pleasant
# Processing Record 43 of Set 12 | macenta
# Processing Record 44 of Set 12 | methoni
# Processing Record 45 of Set 12 | ballina
# Processing Record 46 of Set 12 | inirida
# Processing Record 47 of Set 12 | baghdad
# Processing Record 48 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 49 of Set 12 | blyth
# Processing Record 50 of Set 12 | kamaishi
# Processing Record 1 of Set 13 | caraballeda
# Processing Record 2 of Set 13 | tondi
# Processing Record 3 of Set 13 | verkhnyaya inta
# Processing Record 4 of Set 13 | uige
# Processing Record 5 of Set 13 | nkoteng
# Processing Record 6 of Set 13 | ribnica
# Processing Record 7 of Set 13 | ziarat
# Processing Record 8 of Set 13 | at-bashi
# Processing Record 9 of Set 13 | muzhi
# Processing Record 10 of Set 13 | warmbad
# Processing Record 11 of Set 13 | metro
# Processing Record 12 of Set 13 | corinto
# Processing Record 13 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 14 of Set 13 | acajutla
# Processing Record 15 of Set 13 | lodja
# Processing Record 16 of Set 13 | port keats
# Processing Record 17 of Set 13 | gigmoto
# Processing Record 18 of Set 13 | avrig
# Processing Record 19 of Set 13 | povenets
# Processing Record 20 of Set 13 | marawi
# Processing Record 21 of Set 13 | otjimbingwe
# Processing Record 22 of Set 13 | noumea
# Processing Record 23 of Set 13 | chiang klang
# Processing Record 24 of Set 13 | camabatela
# Processing Record 25 of Set 13 | mandera
# Processing Record 26 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 27 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 13 | shenjiamen
# Processing Record 29 of Set 13 | yarmouth
# Processing Record 30 of Set 13 | pamekasan
# Processing Record 31 of Set 13 | hobyo
# Processing Record 32 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 33 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 13 | vallenar
# Processing Record 35 of Set 13 | ternate
# Processing Record 36 of Set 13 | zhanakorgan
# Processing Record 37 of Set 13 | maketu
# Processing Record 38 of Set 13 | laguna
# Processing Record 39 of Set 13 | poyarkovo
# Processing Record 40 of Set 13 | lujan
# Processing Record 41 of Set 13 | yar-sale
# Processing Record 42 of Set 13 | changping
# Processing Record 43 of Set 13 | taksimo
# Processing Record 44 of Set 13 | caravelas
# Processing Record 45 of Set 13 | general pico
# Processing Record 46 of Set 13 | zhigalovo
# Processing Record 47 of Set 13 | benoni
# Processing Record 48 of Set 13 | chifeng
# Processing Record 49 of Set 13 | na wa
# Processing Record 50 of Set 13 | kushuhum
# Processing Record 1 of Set 14 | karatuzskoye
# Processing Record 2 of Set 14 | ugep
# Processing Record 3 of Set 14 | mahon
# Processing Record 4 of Set 14 | coquimbo
# Processing Record 5 of Set 14 | salinopolis
# Processing Record 6 of Set 14 | sal rei
# Processing Record 7 of Set 14 | mattru
# Processing Record 8 of Set 14 | aksarka
# Processing Record 9 of Set 14 | kyzyl-suu
# Processing Record 10 of Set 14 | tres lagoas
# Processing Record 11 of Set 14 | roald
# Processing Record 12 of Set 14 | ayios kirikos
# City not found. Skipping...
# Processing Record 13 of Set 14 | umm lajj
# Processing Record 14 of Set 14 | hervey bay
# Processing Record 15 of Set 14 | amuntai
# Processing Record 16 of Set 14 | knysna
# Processing Record 17 of Set 14 | baruun-urt
# Processing Record 18 of Set 14 | daru
# Processing Record 19 of Set 14 | amapa
# Processing Record 20 of Set 14 | alta floresta
# Processing Record 21 of Set 14 | mendoza
# Processing Record 22 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 23 of Set 14 | aswan
# Processing Record 24 of Set 14 | sabang
# Processing Record 25 of Set 14 | itarema
# Processing Record 26 of Set 14 | kainantu
# Processing Record 27 of Set 14 | guerrero negro
# Processing Record 28 of Set 14 | anadyr
# Processing Record 29 of Set 14 | najran
# Processing Record 30 of Set 14 | engels
# Processing Record 31 of Set 14 | tingo maria
# Processing Record 32 of Set 14 | coihaique
# Processing Record 33 of Set 14 | kastamonu
# Processing Record 34 of Set 14 | tancanhuitz
# Processing Record 35 of Set 14 | carutapera
# Processing Record 36 of Set 14 | hohhot
# Processing Record 37 of Set 14 | todos santos
# Processing Record 38 of Set 14 | amazar
# Processing Record 39 of Set 14 | buckeye
# Processing Record 40 of Set 14 | nemuro
# Processing Record 41 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 14 | misratah
# Processing Record 43 of Set 14 | montepuez
# Processing Record 44 of Set 14 | glinka
# Processing Record 45 of Set 14 | flinders
# Processing Record 46 of Set 14 | ambunti
# Processing Record 47 of Set 14 | minna
# Processing Record 48 of Set 14 | grand gaube
# Processing Record 49 of Set 14 | nellikkuppam
# Processing Record 50 of Set 14 | jalu
# Processing Record 1 of Set 15 | sobolevo
# Processing Record 2 of Set 15 | madang
# Processing Record 3 of Set 15 | mana
# Processing Record 4 of Set 15 | el carrizo
# Processing Record 5 of Set 15 | pointe michel
# Processing Record 6 of Set 15 | bereda
# Processing Record 7 of Set 15 | asau
# Processing Record 8 of Set 15 | barmer
# Processing Record 9 of Set 15 | balykshi
# Processing Record 10 of Set 15 | qeshm
# Processing Record 11 of Set 15 | rancho palos verdes
# Processing Record 12 of Set 15 | liverpool
# Processing Record 13 of Set 15 | lata
# Processing Record 14 of Set 15 | ashqelon
# Processing Record 15 of Set 15 | undory
# Processing Record 16 of Set 15 | laukaa
# Processing Record 17 of Set 15 | broome
# Processing Record 18 of Set 15 | puqi
# Processing Record 19 of Set 15 | zdzieszowice
# Processing Record 20 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 21 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 22 of Set 15 | bektemir
# Processing Record 23 of Set 15 | marsaxlokk
# Processing Record 24 of Set 15 | black river
# Processing Record 25 of Set 15 | jina
# Processing Record 26 of Set 15 | kutum
# Processing Record 27 of Set 15 | le vauclin
# Processing Record 28 of Set 15 | minbu
# Processing Record 29 of Set 15 | jimma
# Processing Record 30 of Set 15 | tarancon
# Processing Record 31 of Set 15 | tulagi
# Processing Record 32 of Set 15 | svetlyy
# Processing Record 33 of Set 15 | cabra
# Processing Record 34 of Set 15 | tezu
# Processing Record 35 of Set 15 | yanam
# Processing Record 36 of Set 15 | millbrook
# Processing Record 37 of Set 15 | ulverstone
# Processing Record 38 of Set 15 | oktyabrskoye
# Processing Record 39 of Set 15 | mancora
# Processing Record 40 of Set 15 | letnica
# Processing Record 41 of Set 15 | nuevo laredo
# Processing Record 42 of Set 15 | camacha
# Processing Record 43 of Set 15 | fare
# Processing Record 44 of Set 15 | lerwick
# Processing Record 45 of Set 15 | mosquera
# Processing Record 46 of Set 15 | mugur-aksy
# Processing Record 47 of Set 15 | kriel
# Processing Record 48 of Set 15 | bosaso
# Processing Record 49 of Set 15 | farap
# Processing Record 50 of Set 15 | constantine
# Processing Record 1 of Set 16 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 16 | limbang
# Processing Record 3 of Set 16 | ponta delgada
# Processing Record 4 of Set 16 | tiquicheo
# Processing Record 5 of Set 16 | egvekinot
# Processing Record 6 of Set 16 | bulungu
# Processing Record 7 of Set 16 | nampula
# Processing Record 8 of Set 16 | lienz
# Processing Record 9 of Set 16 | nishihara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   East London -33.0153   27.9116     76.14        78          20
# 1        Hobart -42.8794  147.3294     59.05        65         100
# 2        Kargil  34.5667   76.1000    -11.70        92          90
# 3      Khatanga  71.9667  102.5000      1.20        92         100
# 4  Puerto Ayora  -0.7393  -90.3518     80.56        85          89
# 5       Ushuaia -54.8000  -68.3000     49.62        81          75
# 6       Tabasco  18.0000  -92.6667     73.08        76          96
# 7        Barrow  71.2906 -156.7887    -21.98        69           0
# 8        Luanda  -8.8368   13.2343     89.60        48          75
# 9   Tuktoyaktuk  69.4541 -133.0374    -14.80        70         100
#
#    Wind Speed Country Current Description
# 0        8.05      ZA          few clouds
# 1        8.05      AU     overcast clouds
# 2        3.65      IN     overcast clouds
# 3       15.32      RU     overcast clouds
# 4        8.01      EC     overcast clouds
# 5       31.07      AR             drizzle
# 6        6.98      MX     overcast clouds
# 7        3.44      US           clear sky
# 8       10.36      AO       broken clouds
# 9        2.30      CA          light snow

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
